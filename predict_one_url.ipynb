# %%
#importing libraries
import pandas as pd
import numpy as np
import nltk
from nltk.tokenize import sent_tokenize
import re
from nltk.stem import PorterStemmer
from nltk.tag import pos_tag
from nltk.corpus import stopwords
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn import linear_model
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder, LabelBinarizer
from sklearn import metrics
from sklearn.pipeline import Pipeline
from sklearn_pandas import DataFrameMapper
from sklearn.externals import joblib
from flask import Flask, request, jsonify
import webhoseio


wnl = WordNetLemmatizer()
cols = ["uuid", "ord_in_thread", "author", "published", "title", "text", "language", "crawled", "site_url", "country", "domain_rank", "thread_title", "spam_score", "main_img_url", "replies_count", "participants_count", "likes", "comments", "shares", "type"]

# %%
def title_cleaner(title):
    title = re.sub('[^a-zA-Z]',' ', title)
    title = title.lower()
    title = nltk.word_tokenize(title) 
    eng_stopwords = set(stopwords.words("english"))
    title = [w for w in title if not w in eng_stopwords]
    title = ' '.join([word for word in title])
    return(title)

def get_wordnet_pos(treebank_tag):
    '''Treebank to wordnet POS tag'''
    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        return 'n' #basecase POS

# %%
test_data = pd.read_table(u'Data_3-31.csv')
# test_data.to_csv('abeldanger_test_articles.csv')
test_data = test_data[cols]
del test_data['uuid']
test_data = test_data.reset_index()
del test_data['index']
del test_data['thread_title']
del test_data['spam_score']
del test_data['main_img_url']
del test_data['published']
del test_data['crawled']
del test_data['type']
test_data['title'].fillna('', inplace=True)
test_data['text'].fillna('', inplace=True)
test_data.fillna(0, inplace=True)
title = title_cleaner(test_data['title'][0])
text = title_cleaner(test_data['text'][0])
# print(title, text)
test_data[test_data['site_url'] == 'breitbart.com']
# Out:
#      ord_in_thread                     author  \
# 631            0.0                Europa-News
# 632            0.0           Charlie Spiering
# 633            0.0  Thomas D. Williams, Ph.D.
# 634            0.0            Chris Tomlinson
# 635            0.0                  Jeff Poor
# 636            0.0        Breitbart Jerusalem
# 637            0.0        Breitbart Jerusalem
# 638            0.0        Breitbart Jerusalem
# 639           23.0            Midwest Patriot
# 640           24.0                    Dyskord
# 641           25.0                        Rog
# 642           26.0        TrumpClinton Stinks
# 643           27.0                      aa bb
# 644           28.0                zombie_woof
# 645           29.0            ButterflyEffect
# 646           30.0            ButterflyEffect
# 647           31.0            ButterflyEffect
# 648           32.0            ButterflyEffect
# 649           33.0            ButterflyEffect
# 650           34.0           Wilkins Micawber
# 651           35.0           InHocSignoVinces
# 652           36.0                   Iknowall
# 653           37.0                     H.Ryan
# 654           38.0                  ExtremeRC
# 655           39.0                      Troll
# 656           40.0              IVillageIdiot
# 657           41.0                    RazvanM
# 658           42.0           InHocSignoVinces
# 659           43.0             SmackMacDougal
# 660           44.0                   Kathy721
# ..             ...                        ...
# 701           58.0                  Oldmonkey
# 702           59.0              TeaPartyPagan
# 703           60.0                   Tkopfens
# 704           61.0                     mdsman
# 705           62.0                     BruceT
# 706           63.0                    Jusgart
# 707           64.0                  Oldmonkey
# 708           65.0            deplorableTruth
# 709           66.0                   Lie Maid
# 710           67.0              ArdvarkMaster
# 711           68.0                 Bob Sydney
# 712           69.0                    Yojimbo
# 713           70.0                  Ann-marie
# 714           71.0              Hedley LaLarr
# 715           72.0              Hedley LaLarr
# 716           73.0                       Ammy
# 717           74.0                  snowflake
# 718           75.0                cirgregorio
# 719           76.0                         SM
# 720           77.0                  snowflake
# 721           78.0                  snowflake
# 722           79.0                  snowflake
# 723           80.0                  snowflake
# 724           81.0                  snowflake
# 728  breitbart.com      US        967.0          100.0                66.0
# 729  breitbart.com      US        967.0          100.0                66.0
# 730  breitbart.com      US        967.0          100.0                66.0
#
#      likes  comments  shares
# 631    0.0       0.0     0.0
# 632  481.0       0.0   481.0
# 633    0.0       0.0     0.0
# 634    0.0       0.0     0.0
# 635    0.0       0.0     0.0
# 636   40.0       0.0    40.0
# 637   23.0       0.0    23.0
# 638   10.0       0.0    10.0
# 639    0.0       0.0     0.0
# 640    0.0       0.0     0.0
# 641    0.0       0.0     0.0
# 642    0.0       0.0     0.0
# 643    0.0       0.0     0.0
# 644    0.0       0.0     0.0
# 645    0.0       0.0     0.0
# 646    0.0       0.0     0.0
# 647    0.0       0.0     0.0
# 648    0.0       0.0     0.0
# 649    0.0       0.0     0.0
# 650    0.0       0.0     0.0
# 651    0.0       0.0     0.0
# 652    0.0       0.0     0.0
# 653    0.0       0.0     0.0
# 654    0.0       0.0     0.0
# 655    0.0       0.0     0.0
# 656    0.0       0.0     0.0
# 657    0.0       0.0     0.0
# 658    0.0       0.0     0.0
# 659    0.0       0.0     0.0
# 660    0.0       0.0     0.0
# ..     ...       ...     ...
# 701    0.0       0.0     0.0
# 702    0.0       0.0     0.0
# 703    0.0       0.0     0.0
# 704    0.0       0.0     0.0
# 705    0.0       0.0     0.0
# 706    0.0       0.0     0.0
# 707    0.0       0.0     0.0
# 708    0.0       0.0     0.0
# 709    0.0       0.0     0.0
# 710    0.0       0.0     0.0
# 711    0.0       0.0     0.0
# 712    0.0       0.0     0.0
# 713    0.0       0.0     0.0
# 714    0.0       0.0     0.0
# 715    0.0       0.0     0.0
# 716    0.0       0.0     0.0
# 717    0.0       0.0     0.0
# 718    0.0       0.0     0.0
# 719    0.0       0.0     0.0
# 720    0.0       0.0     0.0
# 721    0.0       0.0     0.0
# 722    0.0       0.0     0.0
# 723    0.0       0.0     0.0
# 724    0.0       0.0     0.0
# 725    0.0       0.0     0.0
# 726    0.0       0.0     0.0
# 727    0.0       0.0     0.0
# 728    0.0       0.0     0.0
# 729    0.0       0.0     0.0
# 730    0.0       0.0     0.0
#
# [100 rows x 13 columns]

# %%
title_tag = pos_tag(title.split())
title_clean_wnl = ' '.join([wnl.lemmatize(w,pos=get_wordnet_pos(t)) for w,t in title_tag])
text_tag = pos_tag(text.split())
text_clean_wnl = ' '.join([wnl.lemmatize(w,pos=get_wordnet_pos(t)) for w,t in text_tag])

# %%
le = joblib.load('label_encoder.pkl') 
classifier = joblib.load('classifier.pkl')

# %%
l = ['country','site_url','author','language']
for col in l:
    le.fit(test_data[col])
    test_data[col] = le.transform(test_data[col])
    test_data[col] = test_data[col].astype(float)
test_data['title'] = title_clean_wnl
test_data['text'] = text_clean_wnl
test_data
# Out:
#    ord_in_thread  author                                            title  \
# 0            0.0     0.0  thought greenwich winnetka hillary clinton lose
#
#                                                 text  language  site_url  \
# 0  ap reluctant focus much hillary clinton electi...       0.0       0.0
#
#    country  domain_rank  replies_count  participants_count  likes  comments  \
# 0      0.0        283.0            0.0                 1.0    0.0       0.0
#
#    shares
# 0     0.0

# %%
prediction = classifier.predict_proba(test_data)

# %%
prediction[0]
# Out:
# array([ 0.14,  0.53,  0.33])
